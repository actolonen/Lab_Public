# %% [markdown]
# # NCBI API request to retrieve COG data
#
# ## Introduction
#
# This code makes API requests to the NCBI COG database to retrieve gene COG data for a specific assembly. The retrieved JSON data is parsed into a Python dictionary, and the gene name and COG are printed to an output file.

# %% [markdown]
# ##  Setup

# %%
# Libraries
import requests
import pandas as pd
import time
from requests.exceptions import HTTPError, Timeout, RequestException

# %%
# Flags/config

# genome assembly for analysis
assembly_id = "GCF_000018685.1"

# %%
# File IO

# output file
output_file = f"/home/tolonen/Drives/Genoscope-googledrive/Lab_Projects/Genome_Cphy/COG/cogs_{assembly_id}.txt"

# %% [markdown]
# ## Functions

# %%
# function to make GET request and return dictionary of results

def main_request(url):
    """
    Goal: 
        Fetches gene COG data from the specified NCBI API URL. 
        Parses JSON into dictionary, and returns dictionary.
    
    Args:
        url (str): The NCBI COG API URL for a specific assembly.
    """

    print(f"Attempting to fetch data from: {url}")

    try:   
        # GET request to the API
        response = requests.get(url, timeout=10)
        
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse the JSON response
        data = response.json()
    except Timeout:
        print(f"Request timed out for URL: {url}")
        raise
    except RequestException as e:
        print(f"Request error: {e}")
        raise
    else:
        print("Data fetched successfully.")
        return data

# %%
# function to parse JSON data into dictionary: gene_tag -> COG ID

def get_dictionary(data, all_cogs):
    for item in data['results']:
        gene_tag = item['gene_tag']
        cog_id = item['cog']['cogid']
        all_cogs[gene_tag] = cog_id
    return all_cogs

# %% [markdown]
# ## Main

# %%
# declare all_cogs dictionary
all_cogs = {}

# initialize page number 
page = 1

# loop through API pages, collect data into dictionary: gene_tag -> COG ID
while True:
    url = f"https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly={assembly_id}&format=json&page={page}"

    try:
        # get API data as dictionary
        data = main_request(url)

        # Safety check: prevents 'NoneType' error if main_request fails to raise
        if data is None:
            print(f"Request failed unexpectedly and returned no data for page {page}. Stopping.")
            break

    # --- Error Handling ---
    except HTTPError as err:
        print(f"HTTP Error occurred (Status {err.response.status_code}): {err}")
        break
    except (Timeout, RequestException) as e:
        print(f"A connection or request error occurred: {e}")
        break
    except Exception as e:
        # Catch any other unexpected error (e.g., issues with JSON parsing)
        print(f"An unexpected error occurred: {e}")
        break

    else:
        # make dictionary of COG data
        all_cogs = get_dictionary(data, all_cogs)

        # Prepare for Next Iteration
        page += 1
        print(f"extracted COG data from page {page}")
        time.sleep(1) # Be kind to the API server! Add a delay.


print(f"\nSuccessfully retrieved {len(all_cogs)} gene records for assembly GCF_000018685.1.")
# Out:
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=1
# Data fetched successfully.
# extracted COG data from page 2
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=2
# Data fetched successfully.
# extracted COG data from page 3
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=3
# Data fetched successfully.
# extracted COG data from page 4
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=4
# Data fetched successfully.
# extracted COG data from page 5
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=5
# Data fetched successfully.
# extracted COG data from page 6
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=6
# Data fetched successfully.
# extracted COG data from page 7
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=7
# Data fetched successfully.
# extracted COG data from page 8
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=8
# Data fetched successfully.
# extracted COG data from page 9
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=9
# Data fetched successfully.
# extracted COG data from page 10
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=10
# Data fetched successfully.
# extracted COG data from page 11
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=11
# Data fetched successfully.
# extracted COG data from page 12
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=12
# Data fetched successfully.
# extracted COG data from page 13
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=13
# Data fetched successfully.
# extracted COG data from page 14
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=14
# Data fetched successfully.
# extracted COG data from page 15
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=15
# Data fetched successfully.
# extracted COG data from page 16
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=16
# Data fetched successfully.
# extracted COG data from page 17
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=17
# Data fetched successfully.
# extracted COG data from page 18
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=18
# Data fetched successfully.
# extracted COG data from page 19
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=19
# Data fetched successfully.
# extracted COG data from page 20
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=20
# Data fetched successfully.
# extracted COG data from page 21
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=21
# Data fetched successfully.
# extracted COG data from page 22
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=22
# Data fetched successfully.
# extracted COG data from page 23
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=23
# Data fetched successfully.
# extracted COG data from page 24
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=24
# Data fetched successfully.
# extracted COG data from page 25
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=25
# Data fetched successfully.
# extracted COG data from page 26
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=26
# Data fetched successfully.
# extracted COG data from page 27
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=27
# Data fetched successfully.
# extracted COG data from page 28
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=28
# Data fetched successfully.
# extracted COG data from page 29
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=29
# Data fetched successfully.
# extracted COG data from page 30
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=30
# Data fetched successfully.
# extracted COG data from page 31
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=31
# Data fetched successfully.
# extracted COG data from page 32
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=32
# Data fetched successfully.
# extracted COG data from page 33
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=33
# Data fetched successfully.
# extracted COG data from page 34
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=34
# Data fetched successfully.
# extracted COG data from page 35
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=35
# Data fetched successfully.
# extracted COG data from page 36
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=36
# Data fetched successfully.
# extracted COG data from page 37
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=37
# Data fetched successfully.
# extracted COG data from page 38
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=38
# Data fetched successfully.
# extracted COG data from page 39
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=39
# Data fetched successfully.
# extracted COG data from page 40
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=40
# Data fetched successfully.
# extracted COG data from page 41
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=41
# Data fetched successfully.
# extracted COG data from page 42
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=42
# Data fetched successfully.
# extracted COG data from page 43
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=43
# Data fetched successfully.
# extracted COG data from page 44
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=44
# Data fetched successfully.
# extracted COG data from page 45
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=45
# Data fetched successfully.
# extracted COG data from page 46
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=46
# Data fetched successfully.
# extracted COG data from page 47
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=47
# Data fetched successfully.
# extracted COG data from page 48
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=48
# Data fetched successfully.
# extracted COG data from page 49
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=49
# Data fetched successfully.
# extracted COG data from page 50
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=50
# Data fetched successfully.
# extracted COG data from page 51
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=51
# Data fetched successfully.
# extracted COG data from page 52
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=52
# Data fetched successfully.
# extracted COG data from page 53
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=53
# Data fetched successfully.
# extracted COG data from page 54
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=54
# Data fetched successfully.
# extracted COG data from page 55
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=55
# Data fetched successfully.
# extracted COG data from page 56
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=56
# Data fetched successfully.
# extracted COG data from page 57
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=57
# Data fetched successfully.
# extracted COG data from page 58
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=58
# Data fetched successfully.
# extracted COG data from page 59
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=59
# Data fetched successfully.
# extracted COG data from page 60
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=60
# Data fetched successfully.
# extracted COG data from page 61
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=61
# Data fetched successfully.
# extracted COG data from page 62
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=62
# Data fetched successfully.
# extracted COG data from page 63
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=63
# Data fetched successfully.
# extracted COG data from page 64
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=64
# Data fetched successfully.
# extracted COG data from page 65
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=65
# Data fetched successfully.
# extracted COG data from page 66
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=66
# Data fetched successfully.
# extracted COG data from page 67
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=67
# Data fetched successfully.
# extracted COG data from page 68
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=68
# Data fetched successfully.
# extracted COG data from page 69
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=69
# Data fetched successfully.
# extracted COG data from page 70
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=70
# Data fetched successfully.
# extracted COG data from page 71
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=71
# Data fetched successfully.
# extracted COG data from page 72
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=72
# Data fetched successfully.
# extracted COG data from page 73
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=73
# Data fetched successfully.
# extracted COG data from page 74
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=74
# Data fetched successfully.
# extracted COG data from page 75
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=75
# Data fetched successfully.
# extracted COG data from page 76
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=76
# Data fetched successfully.
# extracted COG data from page 77
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=77
# Data fetched successfully.
# extracted COG data from page 78
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=78
# Data fetched successfully.
# extracted COG data from page 79
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=79
# Data fetched successfully.
# extracted COG data from page 80
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=80
# Data fetched successfully.
# extracted COG data from page 81
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=81
# Data fetched successfully.
# extracted COG data from page 82
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=82
# Data fetched successfully.
# extracted COG data from page 83
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=83
# Data fetched successfully.
# extracted COG data from page 84
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=84
# Data fetched successfully.
# extracted COG data from page 85
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=85
# Data fetched successfully.
# extracted COG data from page 86
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=86
# Data fetched successfully.
# extracted COG data from page 87
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=87
# Data fetched successfully.
# extracted COG data from page 88
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=88
# Data fetched successfully.
# extracted COG data from page 89
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=89
# Data fetched successfully.
# extracted COG data from page 90
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=90
# Data fetched successfully.
# extracted COG data from page 91
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=91
# Data fetched successfully.
# extracted COG data from page 92
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=92
# Data fetched successfully.
# extracted COG data from page 93
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=93
# Data fetched successfully.
# extracted COG data from page 94
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=94
# Data fetched successfully.
# extracted COG data from page 95
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=95
# Data fetched successfully.
# extracted COG data from page 96
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=96
# Data fetched successfully.
# extracted COG data from page 97
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=97
# Data fetched successfully.
# extracted COG data from page 98
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=98
# Data fetched successfully.
# extracted COG data from page 99
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=99
# Data fetched successfully.
# extracted COG data from page 100
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=100
# Data fetched successfully.
# extracted COG data from page 101
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=101
# Data fetched successfully.
# extracted COG data from page 102
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=102
# Data fetched successfully.
# extracted COG data from page 103
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=103
# Data fetched successfully.
# extracted COG data from page 104
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=104
# Data fetched successfully.
# extracted COG data from page 105
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=105
# Data fetched successfully.
# extracted COG data from page 106
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=106
# Data fetched successfully.
# extracted COG data from page 107
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=107
# Data fetched successfully.
# extracted COG data from page 108
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=108
# Data fetched successfully.
# extracted COG data from page 109
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=109
# Data fetched successfully.
# extracted COG data from page 110
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=110
# Data fetched successfully.
# extracted COG data from page 111
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=111
# Data fetched successfully.
# extracted COG data from page 112
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=112
# Data fetched successfully.
# extracted COG data from page 113
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=113
# Data fetched successfully.
# extracted COG data from page 114
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=114
# Data fetched successfully.
# extracted COG data from page 115
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=115
# Data fetched successfully.
# extracted COG data from page 116
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=116
# Data fetched successfully.
# extracted COG data from page 117
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=117
# Data fetched successfully.
# extracted COG data from page 118
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=118
# Data fetched successfully.
# extracted COG data from page 119
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=119
# Data fetched successfully.
# extracted COG data from page 120
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=120
# Data fetched successfully.
# extracted COG data from page 121
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=121
# Data fetched successfully.
# extracted COG data from page 122
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=122
# Data fetched successfully.
# extracted COG data from page 123
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=123
# Data fetched successfully.
# extracted COG data from page 124
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=124
# Data fetched successfully.
# extracted COG data from page 125
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=125
# Data fetched successfully.
# extracted COG data from page 126
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=126
# Data fetched successfully.
# extracted COG data from page 127
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=127
# Data fetched successfully.
# extracted COG data from page 128
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=128
# Data fetched successfully.
# extracted COG data from page 129
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=129
# Data fetched successfully.
# extracted COG data from page 130
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=130
# Data fetched successfully.
# extracted COG data from page 131
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=131
# Data fetched successfully.
# extracted COG data from page 132
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=132
# Data fetched successfully.
# extracted COG data from page 133
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=133
# Data fetched successfully.
# extracted COG data from page 134
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=134
# Data fetched successfully.
# extracted COG data from page 135
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=135
# Data fetched successfully.
# extracted COG data from page 136
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=136
# Data fetched successfully.
# extracted COG data from page 137
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=137
# Data fetched successfully.
# extracted COG data from page 138
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=138
# Data fetched successfully.
# extracted COG data from page 139
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=139
# Data fetched successfully.
# extracted COG data from page 140
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=140
# Data fetched successfully.
# extracted COG data from page 141
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=141
# Data fetched successfully.
# extracted COG data from page 142
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=142
# Data fetched successfully.
# extracted COG data from page 143
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=143
# Data fetched successfully.
# extracted COG data from page 144
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=144
# Data fetched successfully.
# extracted COG data from page 145
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=145
# Data fetched successfully.
# extracted COG data from page 146
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=146
# Data fetched successfully.
# extracted COG data from page 147
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=147
# Data fetched successfully.
# extracted COG data from page 148
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=148
# Data fetched successfully.
# extracted COG data from page 149
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=149
# Data fetched successfully.
# extracted COG data from page 150
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=150
# Data fetched successfully.
# extracted COG data from page 151
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=151
# Data fetched successfully.
# extracted COG data from page 152
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=152
# Data fetched successfully.
# extracted COG data from page 153
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=153
# Data fetched successfully.
# extracted COG data from page 154
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=154
# Data fetched successfully.
# extracted COG data from page 155
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=155
# Data fetched successfully.
# extracted COG data from page 156
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=156
# Data fetched successfully.
# extracted COG data from page 157
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=157
# Data fetched successfully.
# extracted COG data from page 158
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=158
# Data fetched successfully.
# extracted COG data from page 159
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=159
# Data fetched successfully.
# extracted COG data from page 160
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=160
# Data fetched successfully.
# extracted COG data from page 161
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=161
# Data fetched successfully.
# extracted COG data from page 162
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=162
# Data fetched successfully.
# extracted COG data from page 163
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=163
# Data fetched successfully.
# extracted COG data from page 164
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=164
# Data fetched successfully.
# extracted COG data from page 165
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=165
# Data fetched successfully.
# extracted COG data from page 166
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=166
# Data fetched successfully.
# extracted COG data from page 167
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=167
# Data fetched successfully.
# extracted COG data from page 168
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=168
# Data fetched successfully.
# extracted COG data from page 169
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=169
# Data fetched successfully.
# extracted COG data from page 170
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=170
# Data fetched successfully.
# extracted COG data from page 171
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=171
# Data fetched successfully.
# extracted COG data from page 172
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=172
# Data fetched successfully.
# extracted COG data from page 173
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=173
# Data fetched successfully.
# extracted COG data from page 174
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=174
# Data fetched successfully.
# extracted COG data from page 175
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=175
# Data fetched successfully.
# extracted COG data from page 176
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=176
# Data fetched successfully.
# extracted COG data from page 177
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=177
# Data fetched successfully.
# extracted COG data from page 178
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=178
# Data fetched successfully.
# extracted COG data from page 179
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=179
# Data fetched successfully.
# extracted COG data from page 180
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=180
# Data fetched successfully.
# extracted COG data from page 181
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=181
# Data fetched successfully.
# extracted COG data from page 182
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=182
# Data fetched successfully.
# extracted COG data from page 183
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=183
# Data fetched successfully.
# extracted COG data from page 184
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=184
# Data fetched successfully.
# extracted COG data from page 185
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=185
# Data fetched successfully.
# extracted COG data from page 186
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=186
# Data fetched successfully.
# extracted COG data from page 187
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=187
# Data fetched successfully.
# extracted COG data from page 188
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=188
# Data fetched successfully.
# extracted COG data from page 189
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=189
# Data fetched successfully.
# extracted COG data from page 190
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=190
# Data fetched successfully.
# extracted COG data from page 191
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=191
# Data fetched successfully.
# extracted COG data from page 192
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=192
# Data fetched successfully.
# extracted COG data from page 193
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=193
# Data fetched successfully.
# extracted COG data from page 194
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=194
# Data fetched successfully.
# extracted COG data from page 195
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=195
# Data fetched successfully.
# extracted COG data from page 196
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=196
# Data fetched successfully.
# extracted COG data from page 197
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=197
# Data fetched successfully.
# extracted COG data from page 198
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=198
# Data fetched successfully.
# extracted COG data from page 199
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=199
# Data fetched successfully.
# extracted COG data from page 200
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=200
# Data fetched successfully.
# extracted COG data from page 201
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=201
# Data fetched successfully.
# extracted COG data from page 202
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=202
# Data fetched successfully.
# extracted COG data from page 203
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=203
# Data fetched successfully.
# extracted COG data from page 204
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=204
# Data fetched successfully.
# extracted COG data from page 205
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=205
# Data fetched successfully.
# extracted COG data from page 206
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=206
# Data fetched successfully.
# extracted COG data from page 207
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=207
# Data fetched successfully.
# extracted COG data from page 208
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=208
# Data fetched successfully.
# extracted COG data from page 209
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=209
# Data fetched successfully.
# extracted COG data from page 210
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=210
# Data fetched successfully.
# extracted COG data from page 211
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=211
# Data fetched successfully.
# extracted COG data from page 212
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=212
# Data fetched successfully.
# extracted COG data from page 213
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=213
# Data fetched successfully.
# extracted COG data from page 214
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=214
# Data fetched successfully.
# extracted COG data from page 215
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=215
# Data fetched successfully.
# extracted COG data from page 216
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=216
# Data fetched successfully.
# extracted COG data from page 217
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=217
# Data fetched successfully.
# extracted COG data from page 218
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=218
# Data fetched successfully.
# extracted COG data from page 219
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=219
# Data fetched successfully.
# extracted COG data from page 220
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=220
# Data fetched successfully.
# extracted COG data from page 221
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=221
# Data fetched successfully.
# extracted COG data from page 222
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=222
# Data fetched successfully.
# extracted COG data from page 223
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=223
# Data fetched successfully.
# extracted COG data from page 224
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=224
# Data fetched successfully.
# extracted COG data from page 225
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=225
# Data fetched successfully.
# extracted COG data from page 226
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=226
# Data fetched successfully.
# extracted COG data from page 227
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=227
# Data fetched successfully.
# extracted COG data from page 228
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=228
# Data fetched successfully.
# extracted COG data from page 229
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=229
# Data fetched successfully.
# extracted COG data from page 230
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=230
# Data fetched successfully.
# extracted COG data from page 231
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=231
# Data fetched successfully.
# extracted COG data from page 232
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=232
# Data fetched successfully.
# extracted COG data from page 233
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=233
# Data fetched successfully.
# extracted COG data from page 234
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=234
# Data fetched successfully.
# extracted COG data from page 235
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=235
# Data fetched successfully.
# extracted COG data from page 236
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=236
# Data fetched successfully.
# extracted COG data from page 237
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=237
# Data fetched successfully.
# extracted COG data from page 238
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=238
# Data fetched successfully.
# extracted COG data from page 239
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=239
# Data fetched successfully.
# extracted COG data from page 240
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=240
# Data fetched successfully.
# extracted COG data from page 241
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=241
# Data fetched successfully.
# extracted COG data from page 242
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=242
# Data fetched successfully.
# extracted COG data from page 243
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=243
# Data fetched successfully.
# extracted COG data from page 244
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=244
# Data fetched successfully.
# extracted COG data from page 245
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=245
# Data fetched successfully.
# extracted COG data from page 246
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=246
# Data fetched successfully.
# extracted COG data from page 247
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=247
# Data fetched successfully.
# extracted COG data from page 248
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=248
# Data fetched successfully.
# extracted COG data from page 249
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=249
# Data fetched successfully.
# extracted COG data from page 250
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=250
# Data fetched successfully.
# extracted COG data from page 251
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=251
# Data fetched successfully.
# extracted COG data from page 252
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=252
# Data fetched successfully.
# extracted COG data from page 253
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=253
# Data fetched successfully.
# extracted COG data from page 254
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=254
# Data fetched successfully.
# extracted COG data from page 255
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=255
# Data fetched successfully.
# extracted COG data from page 256
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=256
# Data fetched successfully.
# extracted COG data from page 257
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=257
# Data fetched successfully.
# extracted COG data from page 258
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=258
# Data fetched successfully.
# extracted COG data from page 259
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=259
# Data fetched successfully.
# extracted COG data from page 260
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=260
# Data fetched successfully.
# extracted COG data from page 261
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=261
# Data fetched successfully.
# extracted COG data from page 262
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=262
# Data fetched successfully.
# extracted COG data from page 263
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=263
# Data fetched successfully.
# extracted COG data from page 264
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=264
# Data fetched successfully.
# extracted COG data from page 265
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=265
# Data fetched successfully.
# extracted COG data from page 266
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=266
# Data fetched successfully.
# extracted COG data from page 267
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=267
# Data fetched successfully.
# extracted COG data from page 268
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=268
# Data fetched successfully.
# extracted COG data from page 269
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=269
# Data fetched successfully.
# extracted COG data from page 270
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=270
# Data fetched successfully.
# extracted COG data from page 271
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=271
# Data fetched successfully.
# extracted COG data from page 272
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=272
# Data fetched successfully.
# extracted COG data from page 273
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=273
# Data fetched successfully.
# extracted COG data from page 274
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=274
# Data fetched successfully.
# extracted COG data from page 275
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=275
# Data fetched successfully.
# extracted COG data from page 276
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=276
# Data fetched successfully.
# extracted COG data from page 277
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=277
# Data fetched successfully.
# extracted COG data from page 278
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=278
# Data fetched successfully.
# extracted COG data from page 279
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=279
# Data fetched successfully.
# extracted COG data from page 280
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=280
# Data fetched successfully.
# extracted COG data from page 281
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=281
# Data fetched successfully.
# extracted COG data from page 282
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=282
# Data fetched successfully.
# extracted COG data from page 283
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=283
# Data fetched successfully.
# extracted COG data from page 284
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=284
# Data fetched successfully.
# extracted COG data from page 285
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=285
# Data fetched successfully.
# extracted COG data from page 286
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=286
# Data fetched successfully.
# extracted COG data from page 287
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=287
# Data fetched successfully.
# extracted COG data from page 288
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=288
# Data fetched successfully.
# extracted COG data from page 289
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=289
# Data fetched successfully.
# extracted COG data from page 290
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=290
# Data fetched successfully.
# extracted COG data from page 291
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=291
# Data fetched successfully.
# extracted COG data from page 292
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=292
# Data fetched successfully.
# extracted COG data from page 293
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=293
# Data fetched successfully.
# extracted COG data from page 294
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=294
# Data fetched successfully.
# extracted COG data from page 295
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=295
# Data fetched successfully.
# extracted COG data from page 296
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=296
# Data fetched successfully.
# extracted COG data from page 297
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=297
# Data fetched successfully.
# extracted COG data from page 298
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=298
# Data fetched successfully.
# extracted COG data from page 299
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=299
# Data fetched successfully.
# extracted COG data from page 300
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=300
# Data fetched successfully.
# extracted COG data from page 301
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=301
# Data fetched successfully.
# extracted COG data from page 302
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=302
# Data fetched successfully.
# extracted COG data from page 303
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=303
# Data fetched successfully.
# extracted COG data from page 304
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=304
# Data fetched successfully.
# extracted COG data from page 305
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=305
# Data fetched successfully.
# extracted COG data from page 306
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=306
# Data fetched successfully.
# extracted COG data from page 307
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=307
# Data fetched successfully.
# extracted COG data from page 308
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=308
# Data fetched successfully.
# extracted COG data from page 309
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=309
# Data fetched successfully.
# extracted COG data from page 310
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=310
# Data fetched successfully.
# extracted COG data from page 311
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=311
# Data fetched successfully.
# extracted COG data from page 312
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=312
# Data fetched successfully.
# extracted COG data from page 313
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=313
# Data fetched successfully.
# extracted COG data from page 314
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=314
# Data fetched successfully.
# extracted COG data from page 315
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=315
# Data fetched successfully.
# extracted COG data from page 316
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=316
# Data fetched successfully.
# extracted COG data from page 317
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=317
# Data fetched successfully.
# extracted COG data from page 318
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=318
# Data fetched successfully.
# extracted COG data from page 319
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=319
# Data fetched successfully.
# extracted COG data from page 320
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=320
# Data fetched successfully.
# extracted COG data from page 321
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=321
# Data fetched successfully.
# extracted COG data from page 322
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=322
# Data fetched successfully.
# extracted COG data from page 323
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=323
# Data fetched successfully.
# extracted COG data from page 324
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=324
# Data fetched successfully.
# extracted COG data from page 325
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=325
# Data fetched successfully.
# extracted COG data from page 326
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=326
# Data fetched successfully.
# extracted COG data from page 327
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=327
# Data fetched successfully.
# extracted COG data from page 328
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=328
# Data fetched successfully.
# extracted COG data from page 329
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=329
# Data fetched successfully.
# extracted COG data from page 330
# Attempting to fetch data from: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=330
# Request error: 404 Client Error: Not Found for url: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=330
# HTTP Error occurred (Status 404): 404 Client Error: Not Found for url: https://www.ncbi.nlm.nih.gov/research/cog/api/cog/?assembly=GCF_000018685.1&format=json&page=330
#
# Successfully retrieved 3092 gene records for assembly GCF_000018685.1.

# %%
# print COG dictionary to output file

with open(output_file, 'w') as my_out:
    print(f"COGs for each gene in genome {assembly_id} were extracted from the NCBI API using api-request_COG.ipynb\n", file = my_out)
    for key, value in all_cogs.items():
        print(f"Gene: {key}\tCOG: {value}", file = my_out)
